# %%
import requests

# %%
url_2122 = "https://fbref.com/en/squads/18bb7c10/2021-2022/Arsenal-Stats"

# %%
data = requests.get(url_2122)

# %%
data.text
# Out:
# '    \n      \n<!DOCTYPE html>\n<html data-version="klecko-" data-root="/home/fb/deploy/www/base" lang="en" class="no-js" >\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="x-ua-compatible" content="ie=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0" />\n    <link rel="dns-prefetch" href="https://cdn.ssref.net/req/202306261" />\n<!-- Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->\n<script type="text/javascript" async=true>\n    (function() {\n\tvar host = window.location.hostname;\n\tvar element = document.createElement(\'script\');\n\tvar firstScript = document.getElementsByTagName(\'script\')[0];\n\tvar url = \'https://cmp.quantcast.com\'\n\t    .concat(\'/choice/\', \'XwNYEpNeFfhfr\', \'/\', host, \n\t\t    \'/choice.js?tag_version=V2\');\n\tvar uspTries = 0;\n\tvar uspTriesLimit = 3;\n\telement.async = true;\n\telement.type = \'text/javascript\';\n\telement.src = url;\n\t\n\tfirstScript.parentNode.insertB
# ...

# %%
import pandas as pd

# %%
stats2122 = pd.read_html(data.text, match="Scores & Fixtures")[0]

# %%
stats2122
# Out:
#           Date   Time            Comp               Round  Day Venue Result  \
# 0   2021-08-13  20:00  Premier League         Matchweek 1  Fri  Away      L
# 1   2021-08-22  16:30  Premier League         Matchweek 2  Sun  Home      L
# 2   2021-08-25  20:00         EFL Cup        Second round  Wed  Away      W
# 3   2021-08-28  12:30  Premier League         Matchweek 3  Sat  Away      L
# 4   2021-09-11  15:00  Premier League         Matchweek 4  Sat  Home      W
# 5   2021-09-18  15:00  Premier League         Matchweek 5  Sat  Away      W
# 6   2021-09-22  19:45         EFL Cup         Third round  Wed  Home      W
# 7   2021-09-26  16:30  Premier League         Matchweek 6  Sun  Home      W
# 8   2021-10-02  17:30  Premier League         Matchweek 7  Sat  Away      D
# 9   2021-10-18  20:00  Premier League         Matchweek 8  Mon  Home      D
# 10  2021-10-22  20:00  Premier League         Matchweek 9  Fri  Home      W
# ...

# %%
stats2122.drop(["Round", "Day", "GF", "GA", "xG", "xGA", "Poss", "Attendance"], axis=1, inplace=True)

# %%
stats2122
# Out:
#           Date   Time            Comp Venue Result         Opponent  \
# 0   2021-08-13  20:00  Premier League  Away      L        Brentford
# 1   2021-08-22  16:30  Premier League  Home      L          Chelsea
# 2   2021-08-25  20:00         EFL Cup  Away      W        West Brom
# 3   2021-08-28  12:30  Premier League  Away      L  Manchester City
# 4   2021-09-11  15:00  Premier League  Home      W     Norwich City
# 5   2021-09-18  15:00  Premier League  Away      W          Burnley
# 6   2021-09-22  19:45         EFL Cup  Home      W    AFC Wimbledon
# 7   2021-09-26  16:30  Premier League  Home      W        Tottenham
# 8   2021-10-02  17:30  Premier League  Away      D         Brighton
# 9   2021-10-18  20:00  Premier League  Home      D   Crystal Palace
# 10  2021-10-22  20:00  Premier League  Home      W      Aston Villa
# 11  2021-10-26  19:45         EFL Cup  Home      W     Leeds United
# 12  2021-10-30  12:30  Premier League  Away      W   Leicester City
# ...

# %%
stats2122.drop(["Time"], axis=1, inplace=True)

# %%
stats2122
# Out:
#           Date   Time            Comp Venue Result         Opponent Formation  \
# 0   2021-08-13  20:00  Premier League  Away      L        Brentford   4-2-3-1
# 1   2021-08-22  16:30  Premier League  Home      L          Chelsea   4-2-3-1
# 2   2021-08-25  20:00         EFL Cup  Away      W        West Brom   4-2-3-1
# 3   2021-08-28  12:30  Premier League  Away      L  Manchester City     5-4-1
# 4   2021-09-11  15:00  Premier League  Home      W     Norwich City   4-2-3-1
# 5   2021-09-18  15:00  Premier League  Away      W          Burnley   4-1-4-1
# 6   2021-09-22  19:45         EFL Cup  Home      W    AFC Wimbledon   4-3-2-1
# 7   2021-09-26  16:30  Premier League  Home      W        Tottenham   4-2-3-1
# 8   2021-10-02  17:30  Premier League  Away      D         Brighton   4-2-3-1
# 9   2021-10-18  20:00  Premier League  Home      D   Crystal Palace   4-1-4-1
# 10  2021-10-22  20:00  Premier League  Home      W      Aston Villa   4-2-3-1
# ...

# %%
url_2021 = "https://fbref.com/en/squads/18bb7c10/2020-2021/Arsenal-Stats"

# %%
data = requests.get(url_2021)

# %%
stats2021 = pd.read_html(data.text, match="Scores & Fixtures")[0]
stats2021.drop(["Round", "Captain", "Time", "Day", "GF", "GA", "xG", "xGA", "Poss", "Attendance"], axis=1, inplace=True)

# %%
stats2021.drop(["Match Report", "Notes"], axis=1, inplace=True)

# %%
stats_aterta_arsenal = pd.concat([stats2021, stats2122, stats2223])

# %%
stats_aterta_arsenal
# Out:
#           Date              Comp    Venue Result         Opponent Formation  \
# 0   2020-08-29  Community Shield  Neutral      D        Liverpool     3-4-3
# 1   2020-09-12    Premier League     Away      W           Fulham     3-4-3
# 2   2020-09-19    Premier League     Home      W         West Ham     3-4-3
# 3   2020-09-23           EFL Cup     Away      W   Leicester City     3-4-3
# 4   2020-09-28    Premier League     Away      L        Liverpool     3-4-3
# ..         ...               ...      ...    ...              ...       ...
# 45  2023-05-02    Premier League     Home      W          Chelsea     4-3-3
# 46  2023-05-07    Premier League     Away      W    Newcastle Utd     4-3-3
# 47  2023-05-14    Premier League     Home      L         Brighton     4-3-3
# 48  2023-05-20    Premier League     Away      L  Nott'ham Forest     4-3-3
# 49  2023-05-28    Premier League     Home      W           Wolves     4-3-3
#
#            Referee
# 0   Andre Marriner
# ...

# %%
stats_aterta_arsenal.to_csv('arsenal_stats.csv',index=False)
